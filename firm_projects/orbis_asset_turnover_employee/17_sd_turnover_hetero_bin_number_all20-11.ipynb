# %% [markdown]
# # 17_sd_turnover_continous_hetero_bin_number_all20-11_v5

# %%
import numpy as np
import pandas as pd
import fs_qe as fq

# %% [markdown]
# # 1 data process
#
# The imported sample is constructed with the strategy that picking up the US firm with firm-size (turnover) data all available from 2020 to 2011. For details, please see the file ``13``.

# %%
df = pd.read_csv('data_all/us_to_all_postprocess.csv')
df
# Out:
#         Unnamed: 0  year       id   turnover  logturnover  fgrow_log
# 0                3  2014        0  2200000.0    14.603968   0.044452
# 1                6  2017        0  2300000.0    14.648420  -0.044452
# 2                8  2011        1    56200.0    10.936672   0.452955
# 3                9  2012        1    88400.0    11.389627   0.282863
# 4               10  2013        1   117300.0    11.672490   0.272867
# ...            ...   ...      ...        ...          ...        ...
# 104605      126840  2017  1273225        4.0     1.386294   2.564949
# 104606      126841  2016  1273229       95.0     4.553877   0.080852
# 104607      126843  2017  1273230       72.0     4.276666   0.092782
# 104608      126844  2017  1273231       34.0     3.526361   0.516691
# 104609      126845  2017  1273237      237.0     5.468060  -0.957201
#
# [104610 rows x 6 columns]

# %%
fq.scatterplot(df, x='logturnover', xlabel='Log Size (Log Turnover)')

# %% [markdown]
# # 2 sd of firm growth-bar graphs with equal-gap & heterogenous bin sizes 4, 6, 10, 12, 20, 25

# %% [markdown]
# ## 2.1 4 bins

# %%
df1 = fq.generate_equalbinsize(equalbingap=True, n=4)
fq.plot_bars(df1, coefwidth=0.5)

# %% [markdown]
# ## 2.2 6 bins

# %%
df2 = fq.generate_equalbinsize(equalbingap=True, n=6)
fq.plot_bars(df2, coefwidth=0.5)

# %% [markdown]
# ## 2.3 10 bins

# %%
df3 = fq.generate_equalbinsize(equalbingap=True, n=10)
fq.plot_bars(df3, coefwidth=1)

# %% [markdown]
# ## 2.4 12 bins

# %%
df4 = fq.generate_equalbinsize(equalbingap=True, n=12)
fq.plot_bars(df4, coefwidth=1)

# %% [markdown]
# ## 2.5 20 bins

# %%
df5 = fq.generate_equalbinsize(equalbingap=True, n=20)
fq.plot_bars(df5, coefwidth=1)

# %% [markdown]
# ## 2.6 25 bins

# %%
df6 = fq.generate_equalbinsize(equalbingap=True, n=25)
fq.plot_bars(df6, coefwidth=1)
