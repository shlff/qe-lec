# %% [markdown]
# # 04_mean_sd_tail_index_employment_consecutive19-11

# %%
import numpy as np
import pandas as pd
import fs_qe as fq

# %% [markdown]
# # 1 data process
#
# The imported sample is constructed with the strategy that picking up the US firm with firm-size (number of employees) data consecutively from 2019 to 2011. For details, please see the file ``03``.

# %%
df, df2, df3, df4 = fq.dataprocess(file='data/US_employment.csv')

# %%
fq.scatterplot(df, x='lognoe', xlabel='Log Size (Log number of employees)')

# %%
df5 = df2[df2['quantile_ex_1'] == pd.Interval(0.692, 3.178, closed='right') ]
df6 = df2[df2['quantile_ex_1'] == pd.Interval(3.178, 4.22, closed='right') ]
df7 = df2[df2['quantile_ex_1'] == pd.Interval(4.22, 5.746, closed='right') ]
df8 = df2[df2['quantile_ex_1'] == pd.Interval(5.746, 14.648, closed='right') ]

# %%
draw1 = np.array(round(df5['fgrow_log'], ndigits=2))
draw2 = np.array(round(df6['fgrow_log'], ndigits=2))
draw3 = np.array(round(df7['fgrow_log'], ndigits=2))
draw4 = np.array(round(df8['fgrow_log'], ndigits=2))
draw1
# Out:
# array([-0.69,  0.41,  0.41, ..., -0.09, -0.13, -0.04])

# %% [markdown]
# # 2 bar graphs and PDFs

# %% [markdown]
# ## 2.1 bar graphs for mean and standard deviation of firm growth

# %%
fq.plotbars(df3)

# %%
fq.plotbars(df4, ylabel='growth standard deviation')

# %% [markdown]
# ## 2.2 PDFs for growth of firms in 4 bins above, respectively

# %% [markdown]
# The ``empirical func1`` shows the empirical PDF functions of firm growth for firms in **bin 1** above.
#
# The ``empirical func2`` shows the empirical PDF functions of firm growth for firms in **bin 2** above.
#
# The ``empirical func3`` shows the empirical PDF functions of firm growth for firms in **bin 3** above.
#
# The ``empirical func4`` shows the empirical PDF functions of firm growth for firms in **bin 4** above.

# %%
d1 = fq.generating_pdf(draw1)
d2 = fq.generating_pdf(draw2)
d3 = fq.generating_pdf(draw3)
d4 = fq.generating_pdf(draw4)

# %%
x1 = d1['fgrow_mean']
x2 = d2['fgrow_mean']
x3 = d3['fgrow_mean']
x4 = d4['fgrow_mean']

y1 = d1['prob']
y2 = d2['prob']
y3 = d3['prob']
y4 = d4['prob']

# %%
fq.density_plot(x1, x2, x3, x4, y1, y2, y3, y4)

# %% [markdown]
# # 3 tail index

# %% [markdown]
# ## 3.1 function

# %% [markdown]
# ## 3.2 for pooled data

# %%
s_dist1 = df.noe
s_dist2 = df.lognoe
s_dist3 = df.fgrow_log

# %% [markdown]
# The tail index for firm size distribution with firm size measured by number of employees is

# %%
fq.gabaix_est(s_dist1, c=0.01)
# Out:
# 1.781022695723279

# %% [markdown]
# The tail index for log firm size distribution with firm size measured by number of employees is

# %%
fq.gabaix_est(s_dist2, c=0.01)
# Out:
# 21.40595455042527

# %% [markdown]
# The tail index for firm growth distribution with firm size measured by number of employees is

# %%
fq.gabaix_est(s_dist3, c=0.01)
# Out:
# 2.5159459445216155

# %% [markdown]
# ## 3.3 tail index for firm size distribution yearly from 2010 to 2019

# %%
n = 2010
N = 2019
while n <= N:
    x = df[df['year'] == n].noe
    if len(x) == 0: 
        print('None in year', n)
    else:
        print('Tail index in year', n, 'is', fq.gabaix_est(x, c=0.01))
    n += 1
# Out:
# None in year 2010
# Tail index in year 2011 is 1.7136000271823224
# Tail index in year 2012 is 1.8067941060230785
# Tail index in year 2013 is 1.8113078608033861
# Tail index in year 2014 is 1.6580149992458477
# Tail index in year 2015 is 1.9381381076600372
# Tail index in year 2016 is 1.7698621416885358
# Tail index in year 2017 is 1.5660598507989758
# Tail index in year 2018 is 1.7268064050256728
# None in year 2019

# %% [markdown]
# ## 3.4 tail index for log firm size distribution yearly from 2010 to 2019

# %%
n = 2010
N = 2019
while n <= N:
    x = df[df['year'] == n].lognoe
    if len(x) == 0: 
        print('None in year', n)
    else:
        print('Tail index in year', n, 'is', fq.gabaix_est(x, c=0.01))
    n += 1
# Out:
# None in year 2010
# Tail index in year 2011 is 20.381651595203078
# Tail index in year 2012 is 21.49082100085583
# Tail index in year 2013 is 21.608948953643623
# Tail index in year 2014 is 20.196569561521365
# Tail index in year 2015 is 23.23401813322426
# Tail index in year 2016 is 21.207930669661035
# Tail index in year 2017 is 19.18381288858982
# Tail index in year 2018 is 20.77671892811408
# None in year 2019

# %% [markdown]
# ## 3.5 tail index for firm growth distribution yearly from 2010 to 2019

# %%
n = 2010
N = 2019
while n <= N:
    x = df[df['year'] == n].fgrow_log
    if len(x) == 0: 
        print('None in year', n)
    else:
        print('Tail index in year', n, 'is', fq.gabaix_est(x, c=0.01))
    n += 1
# Out:
# None in year 2010
# Tail index in year 2011 is 2.378785276428892
# Tail index in year 2012 is 2.149301537132879
# Tail index in year 2013 is 2.4627307968126706
# Tail index in year 2014 is 2.454089053222306
# Tail index in year 2015 is 2.763193691849807
# Tail index in year 2016 is 2.304068429150866
# Tail index in year 2017 is 3.352385161893782
# Tail index in year 2018 is 2.3920869566216583
# None in year 2019
