# %%
import numpy as np
import pandas as pd
import fs_qe as fq

# %matplotlib inline

# %% [markdown]
# ## 1 import data

# %%
df1 = fq.importdata(file='data/fortune500-2019.csv', year='2019')
df2 = fq.importdata(file='data/fortune500-2018.csv', year='2018')
df3 = fq.importdata(file='data/fortune500-2017.csv', year='2017')
df4 = fq.importdata(file='data/fortune500-2016.csv', year='2016')
df5 = fq.importdata(file='data/fortune500-2015.csv', year='2015')
df6 = fq.importdata(file='data/fortune500-2014.csv', year='2014')
df7 = fq.importdata(file='data/fortune500-2013.csv', year='2013')
df8 = fq.importdata(file='data/fortune500-2012.csv', year='2012')
df9 = fq.importdata(file='data/fortune500-2011.csv', year='2011')
df10 = fq.importdata(file='data/fortune500-2010.csv', year='2010')

df11 = fq.importdata(file='data/fortune500-2009.csv', year='2009')
df12 = fq.importdata(file='data/fortune500-2008.csv', year='2008')
df13 = fq.importdata(file='data/fortune500-2007.csv', year='2007')
df14 = fq.importdata(file='data/fortune500-2006.csv', year='2006')
df15 = fq.importdata(file='data/fortune500-2005.csv', year='2005')
df16 = fq.importdata(file='data/fortune500-2004.csv', year='2004')
df17 = fq.importdata(file='data/fortune500-2003.csv', year='2003')
df18 = fq.importdata(file='data/fortune500-2002.csv', year='2002')
df19 = fq.importdata(file='data/fortune500-2001.csv', year='2001')
df20 = fq.importdata(file='data/fortune500-2000.csv', year='2000')

df21 = fq.importdata(file='data/fortune500-1999.csv', year='1999')
df22 = fq.importdata(file='data/fortune500-1998.csv', year='1998')
df23 = fq.importdata(file='data/fortune500-1997.csv', year='1997')
df24 = fq.importdata(file='data/fortune500-1996.csv', year='1996')
df25 = fq.importdata(file='data/fortune500-1995.csv', year='1995')
df26 = fq.importdata(file='data/fortune500-1994.csv', year='1994')
df27 = fq.importdata(file='data/fortune500-1993.csv', year='1993')
df28 = fq.importdata(file='data/fortune500-1992.csv', year='1992')
df29 = fq.importdata(file='data/fortune500-1991.csv', year='1991')
df30 = fq.importdata(file='data/fortune500-1990.csv', year='1990')

df31 = fq.importdata(file='data/fortune500-1989.csv', year='1989')
df32 = fq.importdata(file='data/fortune500-1988.csv', year='1988')
df33 = fq.importdata(file='data/fortune500-1987.csv', year='1987')
df34 = fq.importdata(file='data/fortune500-1986.csv', year='1986')
df35 = fq.importdata(file='data/fortune500-1985.csv', year='1985')
df36 = fq.importdata(file='data/fortune500-1984.csv', year='1984')
df37 = fq.importdata(file='data/fortune500-1983.csv', year='1983')
df38 = fq.importdata(file='data/fortune500-1982.csv', year='1982')
df39 = fq.importdata(file='data/fortune500-1981.csv', year='1981')
df40 = fq.importdata(file='data/fortune500-1980.csv', year='1980')

df41 = fq.importdata(file='data/fortune500-1979.csv', year='1979')
df42 = fq.importdata(file='data/fortune500-1978.csv', year='1978')
df43 = fq.importdata(file='data/fortune500-1977.csv', year='1977')
df44 = fq.importdata(file='data/fortune500-1976.csv', year='1976')
df45 = fq.importdata(file='data/fortune500-1975.csv', year='1975')
df46 = fq.importdata(file='data/fortune500-1974.csv', year='1974')
df47 = fq.importdata(file='data/fortune500-1973.csv', year='1973')
df48 = fq.importdata(file='data/fortune500-1972.csv', year='1972')
df49 = fq.importdata(file='data/fortune500-1971.csv', year='1971')
df50 = fq.importdata(file='data/fortune500-1970.csv', year='1970')

df51 = fq.importdata(file='data/fortune500-1969.csv', year='1969')
df52 = fq.importdata(file='data/fortune500-1968.csv', year='1968')
df53 = fq.importdata(file='data/fortune500-1967.csv', year='1967')
df54 = fq.importdata(file='data/fortune500-1966.csv', year='1966')
df55 = fq.importdata(file='data/fortune500-1965.csv', year='1965')
df56 = fq.importdata(file='data/fortune500-1964.csv', year='1964')
df57 = fq.importdata(file='data/fortune500-1963.csv', year='1963')
df58 = fq.importdata(file='data/fortune500-1962.csv', year='1962')
df59 = fq.importdata(file='data/fortune500-1961.csv', year='1961')
df60 = fq.importdata(file='data/fortune500-1960.csv', year='1960')

df61 = fq.importdata(file='data/fortune500-1959.csv', year='1959')
df62 = fq.importdata(file='data/fortune500-1958.csv', year='1958')
df63 = fq.importdata(file='data/fortune500-1957.csv', year='1957')
df64 = fq.importdata(file='data/fortune500-1956.csv', year='1956')
df65 = fq.importdata(file='data/fortune500-1955.csv', year='1955')

# %% [markdown]
# ## 2 merge

# %%
df_x1 = pd.merge(df2, df1, on='company')[['2018', '2019']]
df_x2 = pd.merge(df3, df2, on='company')[['2017', '2018']]
df_x3 = pd.merge(df4, df3, on='company')[['2016', '2017']]
df_x4 = pd.merge(df5, df4, on='company')[['2015', '2016']]
df_x5 = pd.merge(df6, df5, on='company')[['2014', '2015']]
df_x6 = pd.merge(df7, df6, on='company')[['2013', '2014']]
df_x7 = pd.merge(df8, df7, on='company')[['2012', '2013']]
df_x8 = pd.merge(df9, df8, on='company')[['2011', '2012']]
df_x9 = pd.merge(df10, df9, on='company')[['2010', '2011']]
df_x10 = pd.merge(df11, df10, on='company')[['2009', '2010']]
df_x11 = pd.merge(df12, df11, on='company')[['2008', '2009']]
df_x12 = pd.merge(df13, df12, on='company')[['2007', '2008']]
df_x13 = pd.merge(df14, df13, on='company')[['2006', '2007']]
df_x14 = pd.merge(df15, df14, on='company')[['2005', '2006']]
df_x15 = pd.merge(df16, df15, on='company')[['2004', '2005']]
df_x16 = pd.merge(df17, df16, on='company')[['2003', '2004']]
df_x17 = pd.merge(df18, df17, on='company')[['2002', '2003']]
df_x18 = pd.merge(df19, df18, on='company')[['2001', '2002']]
df_x19 = pd.merge(df20, df19, on='company')[['2000', '2001']]
df_x20 = pd.merge(df21, df20, on='company')[['1999', '2000']]
df_x21 = pd.merge(df22, df21, on='company')[['1998', '1999']]
df_x22 = pd.merge(df23, df22, on='company')[['1997', '1998']]
df_x23 = pd.merge(df24, df23, on='company')[['1996', '1997']]
df_x24 = pd.merge(df25, df24, on='company')[['1995', '1996']]
df_x25 = pd.merge(df26, df25, on='company')[['1994', '1995']]
df_x26 = pd.merge(df27, df26, on='company')[['1993', '1994']]
df_x27 = pd.merge(df28, df27, on='company')[['1992', '1993']]
df_x28 = pd.merge(df29, df28, on='company')[['1991', '1992']]
df_x29 = pd.merge(df30, df29, on='company')[['1990', '1991']]
df_x30 = pd.merge(df31, df30, on='company')[['1989', '1990']]
df_x31 = pd.merge(df32, df31, on='company')[['1988', '1989']]
df_x32 = pd.merge(df33, df32, on='company')[['1987', '1988']]
df_x33 = pd.merge(df34, df33, on='company')[['1986', '1987']]
df_x34 = pd.merge(df35, df34, on='company')[['1985', '1986']]
df_x35 = pd.merge(df36, df35, on='company')[['1984', '1985']]
df_x36 = pd.merge(df37, df36, on='company')[['1983', '1984']]
df_x37 = pd.merge(df38, df37, on='company')[['1982', '1983']]
df_x38 = pd.merge(df39, df38, on='company')[['1981', '1982']]
df_x39 = pd.merge(df40, df39, on='company')[['1980', '1981']]
df_x40 = pd.merge(df41, df40, on='company')[['1979', '1980']]
df_x41 = pd.merge(df42, df41, on='company')[['1978', '1979']]
df_x42 = pd.merge(df43, df42, on='company')[['1977', '1978']]
df_x43 = pd.merge(df44, df43, on='company')[['1976', '1977']]
df_x44 = pd.merge(df45, df44, on='company')[['1975', '1976']]
df_x45 = pd.merge(df46, df45, on='company')[['1974', '1975']]
df_x46 = pd.merge(df47, df46, on='company')[['1973', '1974']]
df_x47 = pd.merge(df48, df47, on='company')[['1972', '1973']]
df_x48 = pd.merge(df49, df48, on='company')[['1971', '1972']]
df_x49 = pd.merge(df50, df49, on='company')[['1970', '1971']]
df_x50 = pd.merge(df51, df50, on='company')[['1969', '1970']]
df_x51 = pd.merge(df52, df51, on='company')[['1968', '1969']]
df_x52 = pd.merge(df53, df52, on='company')[['1967', '1968']]
df_x53 = pd.merge(df54, df53, on='company')[['1966', '1967']]
df_x54 = pd.merge(df55, df54, on='company')[['1965', '1966']]
df_x55 = pd.merge(df56, df55, on='company')[['1964', '1965']]
df_x56 = pd.merge(df57, df56, on='company')[['1963', '1964']]
df_x57 = pd.merge(df58, df57, on='company')[['1962', '1963']]
df_x58 = pd.merge(df59, df58, on='company')[['1961', '1962']]
df_x59 = pd.merge(df60, df59, on='company')[['1960', '1961']]
df_x60 = pd.merge(df61, df60, on='company')[['1959', '1960']]
df_x61 = pd.merge(df62, df61, on='company')[['1958', '1959']]
df_x62 = pd.merge(df63, df62, on='company')[['1957', '1958']]
df_x63 = pd.merge(df64, df63, on='company')[['1956', '1957']]
df_x64 = pd.merge(df65, df64, on='company')[['1955', '1956']]

# %% [markdown]
# ## 3 firm size and growth

# %%
df_x011 = df_x1.stack()
df_x021 = df_x2.stack()
df_x031 = df_x3.stack()
df_x041 = df_x4.stack()
df_x051 = df_x5.stack()
df_x061 = df_x6.stack()
df_x071 = df_x7.stack()
df_x081 = df_x8.stack()
df_x091 = df_x9.stack()

df_x101 = df_x10.stack()
df_x111 = df_x11.stack()
df_x121 = df_x12.stack()
df_x131 = df_x13.stack()
df_x141 = df_x14.stack()
df_x151 = df_x15.stack()
df_x161 = df_x16.stack()
df_x171 = df_x17.stack()
df_x181 = df_x18.stack()
df_x191 = df_x19.stack()

df_x201 = df_x20.stack()
df_x211 = df_x21.stack()
df_x221 = df_x22.stack()
df_x231 = df_x23.stack()
df_x241 = df_x24.stack()
df_x251 = df_x25.stack()
df_x261 = df_x26.stack()
df_x271 = df_x27.stack()
df_x281 = df_x28.stack()
df_x291 = df_x29.stack()

df_x301 = df_x30.stack()
df_x311 = df_x31.stack()
df_x321 = df_x32.stack()
df_x331 = df_x33.stack()
df_x341 = df_x34.stack()
df_x351 = df_x35.stack()
df_x361 = df_x36.stack()
df_x371 = df_x37.stack()
df_x381 = df_x38.stack()
df_x391 = df_x39.stack()

df_x401 = df_x40.stack()
df_x411 = df_x41.stack()
df_x421 = df_x42.stack()
df_x431 = df_x43.stack()
df_x441 = df_x44.stack()
df_x451 = df_x45.stack()
df_x461 = df_x46.stack()
df_x471 = df_x47.stack()
df_x481 = df_x48.stack()
df_x491 = df_x49.stack()

df_x501 = df_x50.stack()
df_x511 = df_x51.stack()
df_x521 = df_x52.stack()
df_x531 = df_x53.stack()
df_x541 = df_x54.stack()
df_x551 = df_x55.stack()
df_x561 = df_x56.stack()
df_x571 = df_x57.stack()
df_x581 = df_x58.stack()
df_x591 = df_x59.stack()

df_x601 = df_x60.stack()
df_x611 = df_x61.stack()
df_x621 = df_x62.stack()
df_x631 = df_x63.stack()
df_x641 = df_x64.stack()

df_x11
# Out:
#             2008         2009
# 0    378799000.0  405607000.0
# 1    372824000.0  442851000.0
# 2    210783000.0  263159000.0
# 3    182347000.0  148979000.0
# 4    178558000.0  230764000.0
# ..           ...          ...
# 453    4651200.0    4843500.0
# 454    4646400.0    4986900.0
# 455    4638600.0    5163400.0
# 456    4628400.0    5660300.0
# 457    4621000.0    5319000.0
#
# [458 rows x 2 columns]

# %%
df_x012 = df_x011.to_frame().reset_index()
df_x022 = df_x021.to_frame().reset_index()
df_x032 = df_x031.to_frame().reset_index()
df_x042 = df_x041.to_frame().reset_index()
df_x052 = df_x051.to_frame().reset_index()
df_x062 = df_x061.to_frame().reset_index()
df_x072 = df_x071.to_frame().reset_index()
df_x082 = df_x081.to_frame().reset_index()
df_x092 = df_x091.to_frame().reset_index()

df_x102 = df_x101.to_frame().reset_index()
df_x112 = df_x111.to_frame().reset_index()
df_x122 = df_x121.to_frame().reset_index()
df_x132 = df_x131.to_frame().reset_index()
df_x142 = df_x141.to_frame().reset_index()
df_x152 = df_x151.to_frame().reset_index()
df_x162 = df_x161.to_frame().reset_index()
df_x172 = df_x171.to_frame().reset_index()
df_x182 = df_x181.to_frame().reset_index()
df_x192 = df_x191.to_frame().reset_index()

df_x202 = df_x201.to_frame().reset_index()
df_x212 = df_x211.to_frame().reset_index()
df_x222 = df_x221.to_frame().reset_index()
df_x232 = df_x231.to_frame().reset_index()
df_x242 = df_x241.to_frame().reset_index()
df_x252 = df_x251.to_frame().reset_index()
df_x262 = df_x261.to_frame().reset_index()
df_x272 = df_x271.to_frame().reset_index()
df_x282 = df_x281.to_frame().reset_index()
df_x292 = df_x291.to_frame().reset_index()

df_x302 = df_x301.to_frame().reset_index()
df_x312 = df_x311.to_frame().reset_index()
df_x322 = df_x321.to_frame().reset_index()
df_x332 = df_x331.to_frame().reset_index()
df_x342 = df_x341.to_frame().reset_index()
df_x352 = df_x351.to_frame().reset_index()
df_x362 = df_x361.to_frame().reset_index()
df_x372 = df_x371.to_frame().reset_index()
df_x382 = df_x381.to_frame().reset_index()
df_x392 = df_x391.to_frame().reset_index()

df_x402 = df_x401.to_frame().reset_index()
df_x412 = df_x411.to_frame().reset_index()
df_x422 = df_x421.to_frame().reset_index()
df_x432 = df_x431.to_frame().reset_index()
df_x442 = df_x441.to_frame().reset_index()
df_x452 = df_x451.to_frame().reset_index()
df_x462 = df_x461.to_frame().reset_index()
df_x472 = df_x471.to_frame().reset_index()
df_x482 = df_x481.to_frame().reset_index()
df_x492 = df_x491.to_frame().reset_index()

df_x502 = df_x501.to_frame().reset_index()
df_x512 = df_x511.to_frame().reset_index()
df_x522 = df_x521.to_frame().reset_index()
df_x532 = df_x531.to_frame().reset_index()
df_x542 = df_x541.to_frame().reset_index()
df_x552 = df_x551.to_frame().reset_index()
df_x562 = df_x561.to_frame().reset_index()
df_x572 = df_x571.to_frame().reset_index()
df_x582 = df_x581.to_frame().reset_index()
df_x592 = df_x591.to_frame().reset_index()

df_x602 = df_x601.to_frame().reset_index()
df_x612 = df_x611.to_frame().reset_index()
df_x622 = df_x621.to_frame().reset_index()
df_x632 = df_x631.to_frame().reset_index()
df_x642 = df_x641.to_frame().reset_index()

df_x12
# Out:
#             2007         2008
# 0    351139000.0  378799000.0
# 1    347254000.0  372824000.0
# 2    207349000.0  182347000.0
# 3    200567000.0  210783000.0
# 4    172451000.0  178558000.0
# ..           ...          ...
# 427    4470200.0    4900200.0
# 428    4367900.0    4802400.0
# 429    4341300.0    5468000.0
# 430    4327900.0    4651200.0
# 431    4323000.0    4901000.0
#
# [432 rows x 2 columns]

# %%
df_x012.columns = 'id', 'year', 'revenue'
df_x022.columns = 'id', 'year', 'revenue'  
df_x032.columns = 'id', 'year', 'revenue'  
df_x042.columns = 'id', 'year', 'revenue'  
df_x052.columns = 'id', 'year', 'revenue'  
df_x062.columns = 'id', 'year', 'revenue'  
df_x072.columns = 'id', 'year', 'revenue'  
df_x082.columns = 'id', 'year', 'revenue'
df_x092.columns = 'id', 'year', 'revenue'

df_x102.columns = 'id', 'year', 'revenue'
df_x112.columns = 'id', 'year', 'revenue'
df_x122.columns = 'id', 'year', 'revenue'  
df_x132.columns = 'id', 'year', 'revenue'  
df_x142.columns = 'id', 'year', 'revenue'  
df_x152.columns = 'id', 'year', 'revenue'  
df_x162.columns = 'id', 'year', 'revenue'  
df_x172.columns = 'id', 'year', 'revenue'  
df_x182.columns = 'id', 'year', 'revenue'
df_x192.columns = 'id', 'year', 'revenue'

df_x202.columns = 'id', 'year', 'revenue'
df_x212.columns = 'id', 'year', 'revenue'
df_x222.columns = 'id', 'year', 'revenue'  
df_x232.columns = 'id', 'year', 'revenue'  
df_x242.columns = 'id', 'year', 'revenue'  
df_x252.columns = 'id', 'year', 'revenue'  
df_x262.columns = 'id', 'year', 'revenue'  
df_x272.columns = 'id', 'year', 'revenue'  
df_x282.columns = 'id', 'year', 'revenue'
df_x292.columns = 'id', 'year', 'revenue'  

df_x302.columns = 'id', 'year', 'revenue'
df_x312.columns = 'id', 'year', 'revenue'
df_x322.columns = 'id', 'year', 'revenue'  
df_x332.columns = 'id', 'year', 'revenue'  
df_x342.columns = 'id', 'year', 'revenue'  
df_x352.columns = 'id', 'year', 'revenue'  
df_x362.columns = 'id', 'year', 'revenue'  
df_x372.columns = 'id', 'year', 'revenue'  
df_x382.columns = 'id', 'year', 'revenue'
df_x392.columns = 'id', 'year', 'revenue'  

df_x402.columns = 'id', 'year', 'revenue'
df_x412.columns = 'id', 'year', 'revenue'
df_x422.columns = 'id', 'year', 'revenue'  
df_x432.columns = 'id', 'year', 'revenue'  
df_x442.columns = 'id', 'year', 'revenue'  
df_x452.columns = 'id', 'year', 'revenue'  
df_x462.columns = 'id', 'year', 'revenue'  
df_x472.columns = 'id', 'year', 'revenue'  
df_x482.columns = 'id', 'year', 'revenue'
df_x492.columns = 'id', 'year', 'revenue'  

df_x502.columns = 'id', 'year', 'revenue'
df_x512.columns = 'id', 'year', 'revenue'
df_x522.columns = 'id', 'year', 'revenue'  
df_x532.columns = 'id', 'year', 'revenue'  
df_x542.columns = 'id', 'year', 'revenue'  
df_x552.columns = 'id', 'year', 'revenue'  
df_x562.columns = 'id', 'year', 'revenue'  
df_x572.columns = 'id', 'year', 'revenue'  
df_x582.columns = 'id', 'year', 'revenue'
df_x592.columns = 'id', 'year', 'revenue'  

df_x602.columns = 'id', 'year', 'revenue'
df_x612.columns = 'id', 'year', 'revenue'
df_x622.columns = 'id', 'year', 'revenue'  
df_x632.columns = 'id', 'year', 'revenue'  
df_x642.columns = 'id', 'year', 'revenue'  

df_x12
# Out:
#             2007         2008
# 0    351139000.0  378799000.0
# 1    347254000.0  372824000.0
# 2    207349000.0  182347000.0
# 3    200567000.0  210783000.0
# 4    172451000.0  178558000.0
# ..           ...          ...
# 427    4470200.0    4900200.0
# 428    4367900.0    4802400.0
# 429    4341300.0    5468000.0
# 430    4327900.0    4651200.0
# 431    4323000.0    4901000.0
#
# [432 rows x 2 columns]

# %%
df_x013 = df_x012.set_index(['id', 'year'])
df_x023 = df_x022.set_index(['id', 'year'])
df_x033 = df_x032.set_index(['id', 'year'])
df_x043 = df_x042.set_index(['id', 'year'])
df_x053 = df_x052.set_index(['id', 'year'])
df_x063 = df_x062.set_index(['id', 'year'])
df_x073 = df_x072.set_index(['id', 'year'])
df_x083 = df_x082.set_index(['id', 'year'])
df_x093 = df_x092.set_index(['id', 'year'])

df_x103 = df_x102.set_index(['id', 'year'])
df_x113 = df_x112.set_index(['id', 'year'])
df_x123 = df_x122.set_index(['id', 'year'])
df_x133 = df_x132.set_index(['id', 'year'])
df_x143 = df_x142.set_index(['id', 'year'])
df_x153 = df_x152.set_index(['id', 'year'])
df_x163 = df_x162.set_index(['id', 'year'])
df_x173 = df_x172.set_index(['id', 'year'])
df_x183 = df_x182.set_index(['id', 'year'])
df_x193 = df_x192.set_index(['id', 'year'])

df_x203 = df_x202.set_index(['id', 'year'])
df_x213 = df_x212.set_index(['id', 'year'])
df_x223 = df_x222.set_index(['id', 'year'])
df_x233 = df_x232.set_index(['id', 'year'])
df_x243 = df_x242.set_index(['id', 'year'])
df_x253 = df_x252.set_index(['id', 'year'])
df_x263 = df_x262.set_index(['id', 'year'])
df_x273 = df_x272.set_index(['id', 'year'])
df_x283 = df_x282.set_index(['id', 'year'])
df_x293 = df_x292.set_index(['id', 'year'])

df_x303 = df_x302.set_index(['id', 'year'])
df_x313 = df_x312.set_index(['id', 'year'])
df_x323 = df_x322.set_index(['id', 'year'])
df_x333 = df_x332.set_index(['id', 'year'])
df_x343 = df_x342.set_index(['id', 'year'])
df_x353 = df_x352.set_index(['id', 'year'])
df_x363 = df_x362.set_index(['id', 'year'])
df_x373 = df_x372.set_index(['id', 'year'])
df_x383 = df_x382.set_index(['id', 'year'])
df_x393 = df_x392.set_index(['id', 'year'])

df_x403 = df_x402.set_index(['id', 'year'])
df_x413 = df_x412.set_index(['id', 'year'])
df_x423 = df_x422.set_index(['id', 'year'])
df_x433 = df_x432.set_index(['id', 'year'])
df_x443 = df_x442.set_index(['id', 'year'])
df_x453 = df_x452.set_index(['id', 'year'])
df_x463 = df_x462.set_index(['id', 'year'])
df_x473 = df_x472.set_index(['id', 'year'])
df_x483 = df_x482.set_index(['id', 'year'])
df_x493 = df_x492.set_index(['id', 'year'])

df_x503 = df_x502.set_index(['id', 'year'])
df_x513 = df_x512.set_index(['id', 'year'])
df_x523 = df_x522.set_index(['id', 'year'])
df_x533 = df_x532.set_index(['id', 'year'])
df_x543 = df_x542.set_index(['id', 'year'])
df_x553 = df_x552.set_index(['id', 'year'])
df_x563 = df_x562.set_index(['id', 'year'])
df_x573 = df_x572.set_index(['id', 'year'])
df_x583 = df_x582.set_index(['id', 'year'])
df_x593 = df_x592.set_index(['id', 'year'])

df_x603 = df_x602.set_index(['id', 'year'])
df_x613 = df_x612.set_index(['id', 'year'])
df_x623 = df_x622.set_index(['id', 'year'])
df_x633 = df_x632.set_index(['id', 'year'])
df_x643 = df_x642.set_index(['id', 'year'])

df_x13
# Out:
#             2006         2007
# 0    339938000.0  347254000.0
# 1    315654000.0  351139000.0
# 2    192604000.0  207349000.0
# 3    189481000.0  200567000.0
# 4    177210000.0  160126000.0
# ..           ...          ...
# 447    4051200.0    4497600.0
# 448    4002000.0    4323000.0
# 449    4001200.0    4796000.0
# 450    3978900.0    4355900.0
# 451    3962900.0    5127900.0
#
# [452 rows x 2 columns]

# %%
df_x013[df_x013['revenue'] == 'n.a.'] = np.nan
df_x023[df_x023['revenue'] == 'n.a.'] = np.nan
df_x033[df_x033['revenue'] == 'n.a.'] = np.nan
df_x043[df_x043['revenue'] == 'n.a.'] = np.nan
df_x053[df_x053['revenue'] == 'n.a.'] = np.nan
df_x063[df_x063['revenue'] == 'n.a.'] = np.nan
df_x073[df_x073['revenue'] == 'n.a.'] = np.nan
df_x083[df_x083['revenue'] == 'n.a.'] = np.nan
df_x093[df_x093['revenue'] == 'n.a.'] = np.nan

df_x103[df_x103['revenue'] == 'n.a.'] = np.nan
df_x113[df_x113['revenue'] == 'n.a.'] = np.nan
df_x123[df_x123['revenue'] == 'n.a.'] = np.nan
df_x133[df_x133['revenue'] == 'n.a.'] = np.nan
df_x143[df_x143['revenue'] == 'n.a.'] = np.nan
df_x153[df_x153['revenue'] == 'n.a.'] = np.nan
df_x163[df_x163['revenue'] == 'n.a.'] = np.nan
df_x173[df_x173['revenue'] == 'n.a.'] = np.nan
df_x183[df_x183['revenue'] == 'n.a.'] = np.nan
df_x193[df_x193['revenue'] == 'n.a.'] = np.nan

df_x203[df_x203['revenue'] == 'n.a.'] = np.nan
df_x213[df_x213['revenue'] == 'n.a.'] = np.nan
df_x223[df_x223['revenue'] == 'n.a.'] = np.nan
df_x233[df_x233['revenue'] == 'n.a.'] = np.nan
df_x243[df_x243['revenue'] == 'n.a.'] = np.nan
df_x253[df_x253['revenue'] == 'n.a.'] = np.nan
df_x263[df_x263['revenue'] == 'n.a.'] = np.nan
df_x273[df_x273['revenue'] == 'n.a.'] = np.nan
df_x283[df_x283['revenue'] == 'n.a.'] = np.nan
df_x293[df_x293['revenue'] == 'n.a.'] = np.nan

df_x303[df_x303['revenue'] == 'n.a.'] = np.nan
df_x313[df_x313['revenue'] == 'n.a.'] = np.nan
df_x323[df_x323['revenue'] == 'n.a.'] = np.nan
df_x333[df_x333['revenue'] == 'n.a.'] = np.nan
df_x343[df_x343['revenue'] == 'n.a.'] = np.nan
df_x353[df_x353['revenue'] == 'n.a.'] = np.nan
df_x363[df_x363['revenue'] == 'n.a.'] = np.nan
df_x373[df_x373['revenue'] == 'n.a.'] = np.nan
df_x383[df_x383['revenue'] == 'n.a.'] = np.nan
df_x393[df_x393['revenue'] == 'n.a.'] = np.nan

df_x403[df_x403['revenue'] == 'n.a.'] = np.nan
df_x413[df_x413['revenue'] == 'n.a.'] = np.nan
df_x423[df_x423['revenue'] == 'n.a.'] = np.nan
df_x433[df_x433['revenue'] == 'n.a.'] = np.nan
df_x443[df_x443['revenue'] == 'n.a.'] = np.nan
df_x453[df_x453['revenue'] == 'n.a.'] = np.nan
df_x463[df_x463['revenue'] == 'n.a.'] = np.nan
df_x473[df_x473['revenue'] == 'n.a.'] = np.nan
df_x483[df_x483['revenue'] == 'n.a.'] = np.nan
df_x493[df_x493['revenue'] == 'n.a.'] = np.nan

df_x503[df_x503['revenue'] == 'n.a.'] = np.nan
df_x513[df_x513['revenue'] == 'n.a.'] = np.nan
df_x523[df_x523['revenue'] == 'n.a.'] = np.nan
df_x533[df_x533['revenue'] == 'n.a.'] = np.nan
df_x543[df_x543['revenue'] == 'n.a.'] = np.nan
df_x553[df_x553['revenue'] == 'n.a.'] = np.nan
df_x563[df_x563['revenue'] == 'n.a.'] = np.nan
df_x573[df_x573['revenue'] == 'n.a.'] = np.nan
df_x583[df_x583['revenue'] == 'n.a.'] = np.nan
df_x593[df_x593['revenue'] == 'n.a.'] = np.nan

df_x603[df_x603['revenue'] == 'n.a.'] = np.nan
df_x613[df_x613['revenue'] == 'n.a.'] = np.nan
df_x623[df_x623['revenue'] == 'n.a.'] = np.nan
df_x633[df_x633['revenue'] == 'n.a.'] = np.nan
df_x643[df_x643['revenue'] == 'n.a.'] = np.nan

df_x013
# Out:
# /Users/shuhu/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#               revenue
# id  year
# 0   2018  500343000.0
#     2019  514405000.0
# 1   2018  244363000.0
#     2019  290212000.0
# 2   2018  242137000.0
# ...               ...
# 450 2019    6442200.0
# 451 2018    5430000.0
#     2019    9144000.0
# 452 2018    5428900.0
#     2019    6487400.0
#
# [906 rows x 1 columns]

# %%
df_x013[df_x013['revenue'] == '0'] = np.nan
df_x023[df_x023['revenue'] == '0'] = np.nan
df_x033[df_x033['revenue'] == '0'] = np.nan
df_x043[df_x043['revenue'] == '0'] = np.nan
df_x053[df_x053['revenue'] == '0'] = np.nan
df_x063[df_x063['revenue'] == '0'] = np.nan
df_x073[df_x073['revenue'] == '0'] = np.nan
df_x083[df_x083['revenue'] == '0'] = np.nan
df_x093[df_x093['revenue'] == '0'] = np.nan

df_x103[df_x103['revenue'] == '0'] = np.nan
df_x113[df_x113['revenue'] == '0'] = np.nan
df_x123[df_x123['revenue'] == '0'] = np.nan
df_x133[df_x133['revenue'] == '0'] = np.nan
df_x143[df_x143['revenue'] == '0'] = np.nan
df_x153[df_x153['revenue'] == '0'] = np.nan
df_x163[df_x163['revenue'] == '0'] = np.nan
df_x173[df_x173['revenue'] == '0'] = np.nan
df_x183[df_x183['revenue'] == '0'] = np.nan
df_x193[df_x193['revenue'] == '0'] = np.nan

df_x203[df_x203['revenue'] == '0'] = np.nan
df_x213[df_x213['revenue'] == '0'] = np.nan
df_x223[df_x223['revenue'] == '0'] = np.nan
df_x233[df_x233['revenue'] == '0'] = np.nan
df_x243[df_x243['revenue'] == '0'] = np.nan
df_x253[df_x253['revenue'] == '0'] = np.nan
df_x263[df_x263['revenue'] == '0'] = np.nan
df_x273[df_x273['revenue'] == '0'] = np.nan
df_x283[df_x283['revenue'] == '0'] = np.nan
df_x293[df_x293['revenue'] == '0'] = np.nan

df_x303[df_x303['revenue'] == '0'] = np.nan
df_x313[df_x313['revenue'] == '0'] = np.nan
df_x323[df_x323['revenue'] == '0'] = np.nan
df_x333[df_x333['revenue'] == '0'] = np.nan
df_x343[df_x343['revenue'] == '0'] = np.nan
df_x353[df_x353['revenue'] == '0'] = np.nan
df_x363[df_x363['revenue'] == '0'] = np.nan
df_x373[df_x373['revenue'] == '0'] = np.nan
df_x383[df_x383['revenue'] == '0'] = np.nan
df_x393[df_x393['revenue'] == '0'] = np.nan

df_x403[df_x403['revenue'] == '0'] = np.nan
df_x413[df_x413['revenue'] == '0'] = np.nan
df_x423[df_x423['revenue'] == '0'] = np.nan
df_x433[df_x433['revenue'] == '0'] = np.nan
df_x443[df_x443['revenue'] == '0'] = np.nan
df_x453[df_x453['revenue'] == '0'] = np.nan
df_x463[df_x463['revenue'] == '0'] = np.nan
df_x473[df_x473['revenue'] == '0'] = np.nan
df_x483[df_x483['revenue'] == '0'] = np.nan
df_x493[df_x493['revenue'] == '0'] = np.nan

df_x503[df_x503['revenue'] == '0'] = np.nan
df_x513[df_x513['revenue'] == '0'] = np.nan
df_x523[df_x523['revenue'] == '0'] = np.nan
df_x533[df_x533['revenue'] == '0'] = np.nan
df_x543[df_x543['revenue'] == '0'] = np.nan
df_x553[df_x553['revenue'] == '0'] = np.nan
df_x563[df_x563['revenue'] == '0'] = np.nan
df_x573[df_x573['revenue'] == '0'] = np.nan
df_x583[df_x583['revenue'] == '0'] = np.nan
df_x593[df_x593['revenue'] == '0'] = np.nan

df_x603[df_x603['revenue'] == '0'] = np.nan
df_x613[df_x613['revenue'] == '0'] = np.nan
df_x623[df_x623['revenue'] == '0'] = np.nan
df_x633[df_x633['revenue'] == '0'] = np.nan
df_x643[df_x643['revenue'] == '0'] = np.nan

df_x013
# Out:
# /Users/shuhu/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#               revenue
# id  year
# 0   2018  500343000.0
#     2019  514405000.0
# 1   2018  244363000.0
#     2019  290212000.0
# 2   2018  242137000.0
# ...               ...
# 450 2019    6442200.0
# 451 2018    5430000.0
#     2019    9144000.0
# 452 2018    5428900.0
#     2019    6487400.0
#
# [906 rows x 1 columns]

# %%
df_x013['revenue'] = df_x013['revenue'].astype(float)
df_x023['revenue'] = df_x023['revenue'].astype(float)
df_x033['revenue'] = df_x033['revenue'].astype(float)
df_x043['revenue'] = df_x043['revenue'].astype(float)
df_x053['revenue'] = df_x053['revenue'].astype(float)
df_x063['revenue'] = df_x063['revenue'].astype(float)
df_x073['revenue'] = df_x073['revenue'].astype(float)
df_x083['revenue'] = df_x083['revenue'].astype(float)
df_x093['revenue'] = df_x093['revenue'].astype(float)

df_x103['revenue'] = df_x103['revenue'].astype(float)
df_x113['revenue'] = df_x113['revenue'].astype(float)
df_x123['revenue'] = df_x123['revenue'].astype(float)
df_x133['revenue'] = df_x133['revenue'].astype(float)
df_x143['revenue'] = df_x143['revenue'].astype(float)
df_x153['revenue'] = df_x153['revenue'].astype(float)
df_x163['revenue'] = df_x163['revenue'].astype(float)
df_x173['revenue'] = df_x173['revenue'].astype(float)
df_x183['revenue'] = df_x183['revenue'].astype(float)
df_x193['revenue'] = df_x193['revenue'].astype(float)

df_x203['revenue'] = df_x203['revenue'].astype(float)
df_x213['revenue'] = df_x213['revenue'].astype(float)
df_x223['revenue'] = df_x223['revenue'].astype(float)
df_x233['revenue'] = df_x233['revenue'].astype(float)
df_x243['revenue'] = df_x243['revenue'].astype(float)
df_x253['revenue'] = df_x253['revenue'].astype(float)
df_x263['revenue'] = df_x263['revenue'].astype(float)
df_x273['revenue'] = df_x273['revenue'].astype(float)
df_x283['revenue'] = df_x283['revenue'].astype(float)
df_x293['revenue'] = df_x293['revenue'].astype(float)

df_x303['revenue'] = df_x303['revenue'].astype(float)
df_x313['revenue'] = df_x313['revenue'].astype(float)
df_x323['revenue'] = df_x323['revenue'].astype(float)
df_x333['revenue'] = df_x333['revenue'].astype(float)
df_x343['revenue'] = df_x343['revenue'].astype(float)
df_x353['revenue'] = df_x353['revenue'].astype(float)
df_x363['revenue'] = df_x363['revenue'].astype(float)
df_x373['revenue'] = df_x373['revenue'].astype(float)
df_x383['revenue'] = df_x383['revenue'].astype(float)
df_x393['revenue'] = df_x393['revenue'].astype(float)

df_x403['revenue'] = df_x403['revenue'].astype(float)
df_x413['revenue'] = df_x413['revenue'].astype(float)
df_x423['revenue'] = df_x423['revenue'].astype(float)
df_x433['revenue'] = df_x433['revenue'].astype(float)
df_x443['revenue'] = df_x443['revenue'].astype(float)
df_x453['revenue'] = df_x453['revenue'].astype(float)
df_x463['revenue'] = df_x463['revenue'].astype(float)
df_x473['revenue'] = df_x473['revenue'].astype(float)
df_x483['revenue'] = df_x483['revenue'].astype(float)
df_x493['revenue'] = df_x493['revenue'].astype(float)

df_x503['revenue'] = df_x503['revenue'].astype(float)
df_x513['revenue'] = df_x513['revenue'].astype(float)
df_x523['revenue'] = df_x523['revenue'].astype(float)
df_x533['revenue'] = df_x533['revenue'].astype(float)
df_x543['revenue'] = df_x543['revenue'].astype(float)
df_x553['revenue'] = df_x553['revenue'].astype(float)
df_x563['revenue'] = df_x563['revenue'].astype(float)
df_x573['revenue'] = df_x573['revenue'].astype(float)
df_x583['revenue'] = df_x583['revenue'].astype(float)
df_x593['revenue'] = df_x593['revenue'].astype(float)

df_x603['revenue'] = df_x603['revenue'].astype(float)
df_x613['revenue'] = df_x613['revenue'].astype(float)
df_x623['revenue'] = df_x623['revenue'].astype(float)
df_x633['revenue'] = df_x633['revenue'].astype(float)
df_x643['revenue'] = df_x643['revenue'].astype(float)

df_x013
# Out:
#               revenue
# id  year
# 0   2018  500343000.0
#     2019  514405000.0
# 1   2018  244363000.0
#     2019  290212000.0
# 2   2018  242137000.0
# ...               ...
# 450 2019    6442200.0
# 451 2018    5430000.0
#     2019    9144000.0
# 452 2018    5428900.0
#     2019    6487400.0
#
# [906 rows x 1 columns]

# %%
df_x014 = df_x013.reset_index('id')
df_x024 = df_x023.reset_index('id')
df_x034 = df_x033.reset_index('id')
df_x044 = df_x043.reset_index('id')
df_x054 = df_x053.reset_index('id')
df_x064 = df_x063.reset_index('id')
df_x074 = df_x073.reset_index('id')
df_x084 = df_x083.reset_index('id')
df_x094 = df_x093.reset_index('id')

df_x104 = df_x103.reset_index('id')
df_x114 = df_x113.reset_index('id')
df_x124 = df_x123.reset_index('id')
df_x134 = df_x133.reset_index('id')
df_x144 = df_x143.reset_index('id')
df_x154 = df_x153.reset_index('id')
df_x164 = df_x163.reset_index('id')
df_x174 = df_x173.reset_index('id')
df_x184 = df_x183.reset_index('id')
df_x194 = df_x193.reset_index('id')

df_x204 = df_x203.reset_index('id')
df_x214 = df_x213.reset_index('id')
df_x224 = df_x223.reset_index('id')
df_x234 = df_x233.reset_index('id')
df_x244 = df_x243.reset_index('id')
df_x254 = df_x253.reset_index('id')
df_x264 = df_x263.reset_index('id')
df_x274 = df_x273.reset_index('id')
df_x284 = df_x283.reset_index('id')
df_x294 = df_x293.reset_index('id')

df_x304 = df_x303.reset_index('id')
df_x314 = df_x313.reset_index('id')
df_x324 = df_x323.reset_index('id')
df_x334 = df_x333.reset_index('id')
df_x344 = df_x343.reset_index('id')
df_x354 = df_x353.reset_index('id')
df_x364 = df_x363.reset_index('id')
df_x374 = df_x373.reset_index('id')
df_x384 = df_x383.reset_index('id')
df_x394 = df_x393.reset_index('id')

df_x404 = df_x403.reset_index('id')
df_x414 = df_x413.reset_index('id')
df_x424 = df_x423.reset_index('id')
df_x434 = df_x433.reset_index('id')
df_x444 = df_x443.reset_index('id')
df_x454 = df_x453.reset_index('id')
df_x464 = df_x463.reset_index('id')
df_x474 = df_x473.reset_index('id')
df_x484 = df_x483.reset_index('id')
df_x494 = df_x493.reset_index('id')

df_x504 = df_x503.reset_index('id')
df_x514 = df_x513.reset_index('id')
df_x524 = df_x523.reset_index('id')
df_x534 = df_x533.reset_index('id')
df_x544 = df_x543.reset_index('id')
df_x554 = df_x553.reset_index('id')
df_x564 = df_x563.reset_index('id')
df_x574 = df_x573.reset_index('id')
df_x584 = df_x583.reset_index('id')
df_x594 = df_x593.reset_index('id')

df_x604 = df_x603.reset_index('id')
df_x614 = df_x613.reset_index('id')
df_x624 = df_x623.reset_index('id')
df_x634 = df_x633.reset_index('id')
df_x644 = df_x643.reset_index('id')

df_x014['logrevenue'] = np.log(df_x014['revenue'])
df_x024['logrevenue'] = np.log(df_x024['revenue'])
df_x034['logrevenue'] = np.log(df_x034['revenue'])
df_x044['logrevenue'] = np.log(df_x044['revenue'])
df_x054['logrevenue'] = np.log(df_x054['revenue'])
df_x064['logrevenue'] = np.log(df_x064['revenue'])
df_x074['logrevenue'] = np.log(df_x074['revenue'])
df_x084['logrevenue'] = np.log(df_x084['revenue'])
df_x094['logrevenue'] = np.log(df_x094['revenue'])

df_x104['logrevenue'] = np.log(df_x104['revenue'])
df_x114['logrevenue'] = np.log(df_x114['revenue'])
df_x124['logrevenue'] = np.log(df_x124['revenue'])
df_x134['logrevenue'] = np.log(df_x134['revenue'])
df_x144['logrevenue'] = np.log(df_x144['revenue'])
df_x154['logrevenue'] = np.log(df_x154['revenue'])
df_x164['logrevenue'] = np.log(df_x164['revenue'])
df_x174['logrevenue'] = np.log(df_x174['revenue'])
df_x184['logrevenue'] = np.log(df_x184['revenue'])
df_x194['logrevenue'] = np.log(df_x194['revenue'])

df_x204['logrevenue'] = np.log(df_x204['revenue'])
df_x214['logrevenue'] = np.log(df_x214['revenue'])
df_x224['logrevenue'] = np.log(df_x224['revenue'])
df_x234['logrevenue'] = np.log(df_x234['revenue'])
df_x244['logrevenue'] = np.log(df_x244['revenue'])
df_x254['logrevenue'] = np.log(df_x254['revenue'])
df_x264['logrevenue'] = np.log(df_x264['revenue'])
df_x274['logrevenue'] = np.log(df_x274['revenue'])
df_x284['logrevenue'] = np.log(df_x284['revenue'])
df_x294['logrevenue'] = np.log(df_x294['revenue'])

df_x304['logrevenue'] = np.log(df_x304['revenue'])
df_x314['logrevenue'] = np.log(df_x314['revenue'])
df_x324['logrevenue'] = np.log(df_x324['revenue'])
df_x334['logrevenue'] = np.log(df_x334['revenue'])
df_x344['logrevenue'] = np.log(df_x344['revenue'])
df_x354['logrevenue'] = np.log(df_x354['revenue'])
df_x364['logrevenue'] = np.log(df_x364['revenue'])
df_x374['logrevenue'] = np.log(df_x374['revenue'])
df_x384['logrevenue'] = np.log(df_x384['revenue'])
df_x394['logrevenue'] = np.log(df_x394['revenue'])

df_x404['logrevenue'] = np.log(df_x404['revenue'])
df_x414['logrevenue'] = np.log(df_x414['revenue'])
df_x424['logrevenue'] = np.log(df_x424['revenue'])
df_x434['logrevenue'] = np.log(df_x434['revenue'])
df_x444['logrevenue'] = np.log(df_x444['revenue'])
df_x454['logrevenue'] = np.log(df_x454['revenue'])
df_x464['logrevenue'] = np.log(df_x464['revenue'])
df_x474['logrevenue'] = np.log(df_x474['revenue'])
df_x484['logrevenue'] = np.log(df_x484['revenue'])
df_x494['logrevenue'] = np.log(df_x494['revenue'])

df_x504['logrevenue'] = np.log(df_x504['revenue'])
df_x514['logrevenue'] = np.log(df_x514['revenue'])
df_x524['logrevenue'] = np.log(df_x524['revenue'])
df_x534['logrevenue'] = np.log(df_x534['revenue'])
df_x544['logrevenue'] = np.log(df_x544['revenue'])
df_x554['logrevenue'] = np.log(df_x554['revenue'])
df_x564['logrevenue'] = np.log(df_x564['revenue'])
df_x574['logrevenue'] = np.log(df_x574['revenue'])
df_x584['logrevenue'] = np.log(df_x584['revenue'])
df_x594['logrevenue'] = np.log(df_x594['revenue'])

df_x604['logrevenue'] = np.log(df_x604['revenue'])
df_x614['logrevenue'] = np.log(df_x614['revenue'])
df_x624['logrevenue'] = np.log(df_x624['revenue'])
df_x634['logrevenue'] = np.log(df_x634['revenue'])
df_x644['logrevenue'] = np.log(df_x644['revenue'])

df_x014
# Out:
#        id      revenue  logrevenue
# year
# 2018    0  500343000.0   20.030804
# 2019    0  514405000.0   20.058521
# 2018    1  244363000.0   19.314165
# 2019    1  290212000.0   19.486122
# 2018    2  242137000.0   19.305014
# ...   ...          ...         ...
# 2019  450    6442200.0   15.678381
# 2018  451    5430000.0   15.507450
# 2019  451    9144000.0   16.028608
# 2018  452    5428900.0   15.507247
# 2019  452    6487400.0   15.685372
#
# [906 rows x 3 columns]

# %%
# %%time
df_x014['fgrow_log'] = -1 * df_x014.groupby('id')['logrevenue'].diff(periods=-1)
df_x024['fgrow_log'] = -1 * df_x024.groupby('id')['logrevenue'].diff(periods=-1) 
df_x034['fgrow_log'] = -1 * df_x034.groupby('id')['logrevenue'].diff(periods=-1) 
df_x044['fgrow_log'] = -1 * df_x044.groupby('id')['logrevenue'].diff(periods=-1) 
df_x054['fgrow_log'] = -1 * df_x054.groupby('id')['logrevenue'].diff(periods=-1) 
df_x064['fgrow_log'] = -1 * df_x064.groupby('id')['logrevenue'].diff(periods=-1) 
df_x074['fgrow_log'] = -1 * df_x074.groupby('id')['logrevenue'].diff(periods=-1) 
df_x084['fgrow_log'] = -1 * df_x084.groupby('id')['logrevenue'].diff(periods=-1)
df_x094['fgrow_log'] = -1 * df_x094.groupby('id')['logrevenue'].diff(periods=-1)

df_x104['fgrow_log'] = -1 * df_x104.groupby('id')['logrevenue'].diff(periods=-1)
df_x114['fgrow_log'] = -1 * df_x114.groupby('id')['logrevenue'].diff(periods=-1)
df_x124['fgrow_log'] = -1 * df_x124.groupby('id')['logrevenue'].diff(periods=-1) 
df_x134['fgrow_log'] = -1 * df_x134.groupby('id')['logrevenue'].diff(periods=-1) 
df_x144['fgrow_log'] = -1 * df_x144.groupby('id')['logrevenue'].diff(periods=-1) 
df_x154['fgrow_log'] = -1 * df_x154.groupby('id')['logrevenue'].diff(periods=-1) 
df_x164['fgrow_log'] = -1 * df_x164.groupby('id')['logrevenue'].diff(periods=-1) 
df_x174['fgrow_log'] = -1 * df_x174.groupby('id')['logrevenue'].diff(periods=-1) 
df_x184['fgrow_log'] = -1 * df_x184.groupby('id')['logrevenue'].diff(periods=-1)
df_x194['fgrow_log'] = -1 * df_x194.groupby('id')['logrevenue'].diff(periods=-1)

df_x204['fgrow_log'] = -1 * df_x204.groupby('id')['logrevenue'].diff(periods=-1)
df_x214['fgrow_log'] = -1 * df_x214.groupby('id')['logrevenue'].diff(periods=-1)
df_x224['fgrow_log'] = -1 * df_x224.groupby('id')['logrevenue'].diff(periods=-1) 
df_x234['fgrow_log'] = -1 * df_x234.groupby('id')['logrevenue'].diff(periods=-1) 
df_x244['fgrow_log'] = -1 * df_x244.groupby('id')['logrevenue'].diff(periods=-1) 
df_x254['fgrow_log'] = -1 * df_x254.groupby('id')['logrevenue'].diff(periods=-1) 
df_x264['fgrow_log'] = -1 * df_x264.groupby('id')['logrevenue'].diff(periods=-1) 
df_x274['fgrow_log'] = -1 * df_x274.groupby('id')['logrevenue'].diff(periods=-1) 
df_x284['fgrow_log'] = -1 * df_x284.groupby('id')['logrevenue'].diff(periods=-1)
df_x294['fgrow_log'] = -1 * df_x294.groupby('id')['logrevenue'].diff(periods=-1) 

df_x304['fgrow_log'] = -1 * df_x304.groupby('id')['logrevenue'].diff(periods=-1)
df_x314['fgrow_log'] = -1 * df_x314.groupby('id')['logrevenue'].diff(periods=-1)
df_x324['fgrow_log'] = -1 * df_x324.groupby('id')['logrevenue'].diff(periods=-1) 
df_x334['fgrow_log'] = -1 * df_x334.groupby('id')['logrevenue'].diff(periods=-1) 
df_x344['fgrow_log'] = -1 * df_x344.groupby('id')['logrevenue'].diff(periods=-1) 
df_x354['fgrow_log'] = -1 * df_x354.groupby('id')['logrevenue'].diff(periods=-1) 
df_x364['fgrow_log'] = -1 * df_x364.groupby('id')['logrevenue'].diff(periods=-1) 
df_x374['fgrow_log'] = -1 * df_x374.groupby('id')['logrevenue'].diff(periods=-1) 
df_x384['fgrow_log'] = -1 * df_x384.groupby('id')['logrevenue'].diff(periods=-1)
df_x394['fgrow_log'] = -1 * df_x394.groupby('id')['logrevenue'].diff(periods=-1) 

df_x404['fgrow_log'] = -1 * df_x404.groupby('id')['logrevenue'].diff(periods=-1)
df_x414['fgrow_log'] = -1 * df_x414.groupby('id')['logrevenue'].diff(periods=-1)
df_x424['fgrow_log'] = -1 * df_x424.groupby('id')['logrevenue'].diff(periods=-1) 
df_x434['fgrow_log'] = -1 * df_x434.groupby('id')['logrevenue'].diff(periods=-1) 
df_x444['fgrow_log'] = -1 * df_x444.groupby('id')['logrevenue'].diff(periods=-1) 
df_x454['fgrow_log'] = -1 * df_x454.groupby('id')['logrevenue'].diff(periods=-1) 
df_x464['fgrow_log'] = -1 * df_x464.groupby('id')['logrevenue'].diff(periods=-1) 
df_x474['fgrow_log'] = -1 * df_x474.groupby('id')['logrevenue'].diff(periods=-1) 
df_x484['fgrow_log'] = -1 * df_x484.groupby('id')['logrevenue'].diff(periods=-1)
df_x494['fgrow_log'] = -1 * df_x494.groupby('id')['logrevenue'].diff(periods=-1) 

df_x504['fgrow_log'] = -1 * df_x504.groupby('id')['logrevenue'].diff(periods=-1)
df_x514['fgrow_log'] = -1 * df_x514.groupby('id')['logrevenue'].diff(periods=-1)
df_x524['fgrow_log'] = -1 * df_x524.groupby('id')['logrevenue'].diff(periods=-1) 
df_x534['fgrow_log'] = -1 * df_x534.groupby('id')['logrevenue'].diff(periods=-1) 
df_x544['fgrow_log'] = -1 * df_x544.groupby('id')['logrevenue'].diff(periods=-1) 
df_x554['fgrow_log'] = -1 * df_x554.groupby('id')['logrevenue'].diff(periods=-1) 
df_x564['fgrow_log'] = -1 * df_x564.groupby('id')['logrevenue'].diff(periods=-1) 
df_x574['fgrow_log'] = -1 * df_x574.groupby('id')['logrevenue'].diff(periods=-1) 
df_x584['fgrow_log'] = -1 * df_x584.groupby('id')['logrevenue'].diff(periods=-1)
df_x594['fgrow_log'] = -1 * df_x594.groupby('id')['logrevenue'].diff(periods=-1) 

df_x604['fgrow_log'] = -1 * df_x604.groupby('id')['logrevenue'].diff(periods=-1)
df_x614['fgrow_log'] = -1 * df_x614.groupby('id')['logrevenue'].diff(periods=-1)
df_x624['fgrow_log'] = -1 * df_x624.groupby('id')['logrevenue'].diff(periods=-1) 
df_x634['fgrow_log'] = -1 * df_x634.groupby('id')['logrevenue'].diff(periods=-1) 
df_x644['fgrow_log'] = -1 * df_x644.groupby('id')['logrevenue'].diff(periods=-1) 

df_x014[0:30]
# Out:
# CPU times: user 5.12 s, sys: 65.1 ms, total: 5.18 s
# Wall time: 5.23 s
#       id      revenue  logrevenue  fgrow_log
# year
# 2018   0  500343000.0   20.030804   0.027717
# 2019   0  514405000.0   20.058521        NaN
# 2018   1  244363000.0   19.314165   0.171957
# 2019   1  290212000.0   19.486122        NaN
# 2018   2  242137000.0   19.305014   0.023268
# 2019   2  247837000.0   19.328282        NaN
# 2018   3  229234000.0   19.250254   0.147229
# 2019   3  265595000.0   19.397483        NaN
# 2018   4  201159000.0   19.119606   0.117532
# 2019   4  226247000.0   19.237138        NaN
# 2018   5  198533000.0   19.106466   0.048298
# 2019   5  208357000.0   19.154764        NaN
# 2018   6  184765000.0   19.034595   0.051754
# 2019   6  194579000.0   19.086349        NaN
# 2018   7  177866000.0   18.996541   0.269523
# 2019   7  232887000.0   19.266064        NaN
# 2018   8  160546000.0   18.894091   0.061655
# 2019   8  170756000.0   18.955746        NaN
# ...

# %%
df_x015 = df_x014.dropna().reset_index()
df_x025 = df_x024.dropna().reset_index()
df_x035 = df_x034.dropna().reset_index()
df_x045 = df_x044.dropna().reset_index()
df_x055 = df_x054.dropna().reset_index()
df_x065 = df_x064.dropna().reset_index()
df_x075 = df_x074.dropna().reset_index()
df_x085 = df_x084.dropna().reset_index()
df_x095 = df_x094.dropna().reset_index()

df_x105 = df_x104.dropna().reset_index()
df_x115 = df_x114.dropna().reset_index()
df_x125 = df_x124.dropna().reset_index()
df_x135 = df_x134.dropna().reset_index()
df_x145 = df_x144.dropna().reset_index()
df_x155 = df_x154.dropna().reset_index()
df_x165 = df_x164.dropna().reset_index()
df_x175 = df_x174.dropna().reset_index()
df_x185 = df_x184.dropna().reset_index()
df_x195 = df_x194.dropna().reset_index()

df_x205 = df_x204.dropna().reset_index()
df_x215 = df_x214.dropna().reset_index()
df_x225 = df_x224.dropna().reset_index()
df_x235 = df_x234.dropna().reset_index()
df_x245 = df_x244.dropna().reset_index()
df_x255 = df_x254.dropna().reset_index()
df_x265 = df_x264.dropna().reset_index()
df_x275 = df_x274.dropna().reset_index()
df_x285 = df_x284.dropna().reset_index()
df_x295 = df_x294.dropna().reset_index()

df_x305 = df_x304.dropna().reset_index()
df_x315 = df_x314.dropna().reset_index()
df_x325 = df_x324.dropna().reset_index()
df_x335 = df_x334.dropna().reset_index()
df_x345 = df_x344.dropna().reset_index()
df_x355 = df_x354.dropna().reset_index()
df_x365 = df_x364.dropna().reset_index()
df_x375 = df_x374.dropna().reset_index()
df_x385 = df_x384.dropna().reset_index()
df_x395 = df_x394.dropna().reset_index()

df_x405 = df_x404.dropna().reset_index()
df_x415 = df_x414.dropna().reset_index()
df_x425 = df_x424.dropna().reset_index()
df_x435 = df_x434.dropna().reset_index()
df_x445 = df_x444.dropna().reset_index()
df_x455 = df_x454.dropna().reset_index()
df_x465 = df_x464.dropna().reset_index()
df_x475 = df_x474.dropna().reset_index()
df_x485 = df_x484.dropna().reset_index()
df_x495 = df_x494.dropna().reset_index()

df_x505 = df_x504.dropna().reset_index()
df_x515 = df_x514.dropna().reset_index()
df_x525 = df_x524.dropna().reset_index()
df_x535 = df_x534.dropna().reset_index()
df_x545 = df_x544.dropna().reset_index()
df_x555 = df_x554.dropna().reset_index()
df_x565 = df_x564.dropna().reset_index()
df_x575 = df_x574.dropna().reset_index()
df_x585 = df_x584.dropna().reset_index()
df_x595 = df_x594.dropna().reset_index()

df_x605 = df_x604.dropna().reset_index()
df_x615 = df_x614.dropna().reset_index()
df_x625 = df_x624.dropna().reset_index()
df_x635 = df_x634.dropna().reset_index()
df_x645 = df_x644.dropna().reset_index()

df_x015[0:30]
# Out:
#     year  id      revenue  logrevenue  fgrow_log
# 0   2018   0  500343000.0   20.030804   0.027717
# 1   2018   1  244363000.0   19.314165   0.171957
# 2   2018   2  242137000.0   19.305014   0.023268
# 3   2018   3  229234000.0   19.250254   0.147229
# 4   2018   4  201159000.0   19.119606   0.117532
# 5   2018   5  198533000.0   19.106466   0.048298
# 6   2018   6  184765000.0   19.034595   0.051754
# 7   2018   7  177866000.0   18.996541   0.269523
# 8   2018   8  160546000.0   18.894091   0.061655
# 9   2018   9  157311000.0   18.873735  -0.067459
# 10  2018  10  156776000.0   18.870329   0.022466
# 11  2018  11  153143800.0   18.846888   0.092227
# 12  2018  12  134533000.0   18.717320   0.212218
# 13  2018  13  129976000.0   18.682860   0.051236
# 14  2018  14  122662000.0   18.624943  -0.012304
# 15  2018  15  122274000.0   18.621775  -0.016542
# 16  2018  16  118214000.0   18.588007   0.106792
# 17  2018  17  113899000.0   18.550823   0.143025
# ...

# %%
# step 6

df_x016 = df_x015[df_x015['fgrow_log'] != 0.0]
df_x026 = df_x025[df_x025['fgrow_log'] != 0.0]
df_x036 = df_x035[df_x035['fgrow_log'] != 0.0]
df_x046 = df_x045[df_x045['fgrow_log'] != 0.0]
df_x056 = df_x055[df_x055['fgrow_log'] != 0.0]
df_x066 = df_x065[df_x065['fgrow_log'] != 0.0]
df_x076 = df_x075[df_x075['fgrow_log'] != 0.0]
df_x086 = df_x085[df_x085['fgrow_log'] != 0.0]
df_x096 = df_x095[df_x095['fgrow_log'] != 0.0]

df_x106 = df_x105[df_x105['fgrow_log'] != 0.0]
df_x116 = df_x115[df_x115['fgrow_log'] != 0.0]
df_x126 = df_x125[df_x125['fgrow_log'] != 0.0]
df_x136 = df_x135[df_x135['fgrow_log'] != 0.0]
df_x146 = df_x145[df_x145['fgrow_log'] != 0.0]
df_x156 = df_x155[df_x155['fgrow_log'] != 0.0]
df_x166 = df_x165[df_x165['fgrow_log'] != 0.0]
df_x176 = df_x175[df_x175['fgrow_log'] != 0.0]
df_x186 = df_x185[df_x185['fgrow_log'] != 0.0]
df_x196 = df_x195[df_x195['fgrow_log'] != 0.0]

df_x206 = df_x205[df_x205['fgrow_log'] != 0.0]
df_x216 = df_x215[df_x215['fgrow_log'] != 0.0]
df_x226 = df_x225[df_x225['fgrow_log'] != 0.0]
df_x236 = df_x235[df_x235['fgrow_log'] != 0.0]
df_x246 = df_x245[df_x245['fgrow_log'] != 0.0]
df_x256 = df_x255[df_x255['fgrow_log'] != 0.0]
df_x266 = df_x265[df_x265['fgrow_log'] != 0.0]
df_x276 = df_x275[df_x275['fgrow_log'] != 0.0]
df_x286 = df_x285[df_x285['fgrow_log'] != 0.0]
df_x296 = df_x295[df_x295['fgrow_log'] != 0.0]

df_x306 = df_x305[df_x305['fgrow_log'] != 0.0]
df_x316 = df_x315[df_x315['fgrow_log'] != 0.0]
df_x326 = df_x325[df_x325['fgrow_log'] != 0.0]
df_x336 = df_x335[df_x335['fgrow_log'] != 0.0]
df_x346 = df_x345[df_x345['fgrow_log'] != 0.0]
df_x356 = df_x355[df_x355['fgrow_log'] != 0.0]
df_x366 = df_x365[df_x365['fgrow_log'] != 0.0]
df_x376 = df_x375[df_x375['fgrow_log'] != 0.0]
df_x386 = df_x385[df_x385['fgrow_log'] != 0.0]
df_x396 = df_x395[df_x395['fgrow_log'] != 0.0]

df_x406 = df_x405[df_x405['fgrow_log'] != 0.0]
df_x416 = df_x415[df_x415['fgrow_log'] != 0.0]
df_x426 = df_x425[df_x425['fgrow_log'] != 0.0]
df_x436 = df_x435[df_x435['fgrow_log'] != 0.0]
df_x446 = df_x445[df_x445['fgrow_log'] != 0.0]
df_x456 = df_x455[df_x455['fgrow_log'] != 0.0]
df_x466 = df_x465[df_x465['fgrow_log'] != 0.0]
df_x476 = df_x475[df_x475['fgrow_log'] != 0.0]
df_x486 = df_x485[df_x485['fgrow_log'] != 0.0]
df_x496 = df_x495[df_x495['fgrow_log'] != 0.0]

df_x506 = df_x505[df_x505['fgrow_log'] != 0.0]
df_x516 = df_x515[df_x515['fgrow_log'] != 0.0]
df_x526 = df_x525[df_x525['fgrow_log'] != 0.0]
df_x536 = df_x535[df_x535['fgrow_log'] != 0.0]
df_x546 = df_x545[df_x545['fgrow_log'] != 0.0]
df_x556 = df_x555[df_x555['fgrow_log'] != 0.0]
df_x566 = df_x565[df_x565['fgrow_log'] != 0.0]
df_x576 = df_x575[df_x575['fgrow_log'] != 0.0]
df_x586 = df_x585[df_x585['fgrow_log'] != 0.0]
df_x596 = df_x595[df_x595['fgrow_log'] != 0.0]

df_x606 = df_x605[df_x605['fgrow_log'] != 0.0]
df_x616 = df_x615[df_x615['fgrow_log'] != 0.0]
df_x626 = df_x625[df_x625['fgrow_log'] != 0.0]
df_x636 = df_x635[df_x635['fgrow_log'] != 0.0]
df_x646 = df_x645[df_x645['fgrow_log'] != 0.0]

# %%
# step 7

df_x017 = df_x016[df_x016['fgrow_log'] != np.inf]
df_x027 = df_x026[df_x026['fgrow_log'] != np.inf]
df_x037 = df_x036[df_x036['fgrow_log'] != np.inf]
df_x047 = df_x046[df_x046['fgrow_log'] != np.inf]
df_x057 = df_x056[df_x056['fgrow_log'] != np.inf]
df_x067 = df_x066[df_x066['fgrow_log'] != np.inf]
df_x077 = df_x076[df_x076['fgrow_log'] != np.inf]
df_x087 = df_x086[df_x086['fgrow_log'] != np.inf]
df_x097 = df_x096[df_x096['fgrow_log'] != np.inf]

df_x107 = df_x106[df_x106['fgrow_log'] != np.inf]
df_x117 = df_x116[df_x116['fgrow_log'] != np.inf]
df_x127 = df_x126[df_x126['fgrow_log'] != np.inf]
df_x137 = df_x136[df_x136['fgrow_log'] != np.inf]
df_x147 = df_x146[df_x146['fgrow_log'] != np.inf]
df_x157 = df_x156[df_x156['fgrow_log'] != np.inf]
df_x167 = df_x166[df_x166['fgrow_log'] != np.inf]
df_x177 = df_x176[df_x176['fgrow_log'] != np.inf]
df_x187 = df_x186[df_x186['fgrow_log'] != np.inf]
df_x197 = df_x196[df_x196['fgrow_log'] != np.inf]

df_x207 = df_x206[df_x206['fgrow_log'] != np.inf]
df_x217 = df_x216[df_x216['fgrow_log'] != np.inf]
df_x227 = df_x226[df_x226['fgrow_log'] != np.inf]
df_x237 = df_x236[df_x236['fgrow_log'] != np.inf]
df_x247 = df_x246[df_x246['fgrow_log'] != np.inf]
df_x257 = df_x256[df_x256['fgrow_log'] != np.inf]
df_x267 = df_x266[df_x266['fgrow_log'] != np.inf]
df_x277 = df_x276[df_x276['fgrow_log'] != np.inf]
df_x287 = df_x286[df_x286['fgrow_log'] != np.inf]
df_x297 = df_x296[df_x296['fgrow_log'] != np.inf]

df_x307 = df_x306[df_x306['fgrow_log'] != np.inf]
df_x317 = df_x316[df_x316['fgrow_log'] != np.inf]
df_x327 = df_x326[df_x326['fgrow_log'] != np.inf]
df_x337 = df_x336[df_x336['fgrow_log'] != np.inf]
df_x347 = df_x346[df_x346['fgrow_log'] != np.inf]
df_x357 = df_x356[df_x356['fgrow_log'] != np.inf]
df_x367 = df_x366[df_x366['fgrow_log'] != np.inf]
df_x377 = df_x376[df_x376['fgrow_log'] != np.inf]
df_x387 = df_x386[df_x386['fgrow_log'] != np.inf]
df_x397 = df_x396[df_x396['fgrow_log'] != np.inf]

df_x407 = df_x406[df_x406['fgrow_log'] != np.inf]
df_x417 = df_x416[df_x416['fgrow_log'] != np.inf]
df_x427 = df_x426[df_x426['fgrow_log'] != np.inf]
df_x437 = df_x436[df_x436['fgrow_log'] != np.inf]
df_x447 = df_x446[df_x446['fgrow_log'] != np.inf]
df_x457 = df_x456[df_x456['fgrow_log'] != np.inf]
df_x467 = df_x466[df_x466['fgrow_log'] != np.inf]
df_x477 = df_x476[df_x476['fgrow_log'] != np.inf]
df_x487 = df_x486[df_x486['fgrow_log'] != np.inf]
df_x497 = df_x496[df_x496['fgrow_log'] != np.inf]

df_x507 = df_x506[df_x506['fgrow_log'] != np.inf]
df_x517 = df_x516[df_x516['fgrow_log'] != np.inf]
df_x527 = df_x526[df_x526['fgrow_log'] != np.inf]
df_x537 = df_x536[df_x536['fgrow_log'] != np.inf]
df_x547 = df_x546[df_x546['fgrow_log'] != np.inf]
df_x557 = df_x556[df_x556['fgrow_log'] != np.inf]
df_x567 = df_x566[df_x566['fgrow_log'] != np.inf]
df_x577 = df_x576[df_x576['fgrow_log'] != np.inf]
df_x587 = df_x586[df_x586['fgrow_log'] != np.inf]
df_x597 = df_x596[df_x596['fgrow_log'] != np.inf]

df_x607 = df_x606[df_x606['fgrow_log'] != np.inf]
df_x617 = df_x616[df_x616['fgrow_log'] != np.inf]
df_x627 = df_x626[df_x626['fgrow_log'] != np.inf]
df_x637 = df_x636[df_x636['fgrow_log'] != np.inf]
df_x647 = df_x646[df_x646['fgrow_log'] != np.inf]

# %%
# step 8

df_x018 = df_x017[df_x017['fgrow_log'] != - np.inf]
df_x028 = df_x027[df_x027['fgrow_log'] != - np.inf]
df_x038 = df_x037[df_x037['fgrow_log'] != - np.inf]
df_x048 = df_x047[df_x047['fgrow_log'] != - np.inf]
df_x058 = df_x057[df_x057['fgrow_log'] != - np.inf]
df_x068 = df_x067[df_x067['fgrow_log'] != - np.inf]
df_x078 = df_x077[df_x077['fgrow_log'] != - np.inf]
df_x088 = df_x087[df_x087['fgrow_log'] != - np.inf]
df_x098 = df_x097[df_x097['fgrow_log'] != - np.inf]

df_x108 = df_x107[df_x107['fgrow_log'] != - np.inf]
df_x118 = df_x117[df_x117['fgrow_log'] != - np.inf]
df_x128 = df_x127[df_x127['fgrow_log'] != - np.inf]
df_x138 = df_x137[df_x137['fgrow_log'] != - np.inf]
df_x148 = df_x147[df_x147['fgrow_log'] != - np.inf]
df_x158 = df_x157[df_x157['fgrow_log'] != - np.inf]
df_x168 = df_x167[df_x167['fgrow_log'] != - np.inf]
df_x178 = df_x177[df_x177['fgrow_log'] != - np.inf]
df_x188 = df_x187[df_x187['fgrow_log'] != - np.inf]
df_x198 = df_x197[df_x197['fgrow_log'] != - np.inf]

df_x208 = df_x207[df_x207['fgrow_log'] != - np.inf]
df_x218 = df_x217[df_x217['fgrow_log'] != - np.inf]
df_x228 = df_x227[df_x227['fgrow_log'] != - np.inf]
df_x238 = df_x237[df_x237['fgrow_log'] != - np.inf]
df_x248 = df_x247[df_x247['fgrow_log'] != - np.inf]
df_x258 = df_x257[df_x257['fgrow_log'] != - np.inf]
df_x268 = df_x267[df_x267['fgrow_log'] != - np.inf]
df_x278 = df_x277[df_x277['fgrow_log'] != - np.inf]
df_x288 = df_x287[df_x287['fgrow_log'] != - np.inf]
df_x298 = df_x297[df_x297['fgrow_log'] != - np.inf]

df_x308 = df_x307[df_x307['fgrow_log'] != - np.inf]
df_x318 = df_x317[df_x317['fgrow_log'] != - np.inf]
df_x328 = df_x327[df_x327['fgrow_log'] != - np.inf]
df_x338 = df_x337[df_x337['fgrow_log'] != - np.inf]
df_x348 = df_x347[df_x347['fgrow_log'] != - np.inf]
df_x358 = df_x357[df_x357['fgrow_log'] != - np.inf]
df_x368 = df_x367[df_x367['fgrow_log'] != - np.inf]
df_x378 = df_x377[df_x377['fgrow_log'] != - np.inf]
df_x388 = df_x387[df_x387['fgrow_log'] != - np.inf]
df_x398 = df_x397[df_x397['fgrow_log'] != - np.inf]

df_x408 = df_x407[df_x407['fgrow_log'] != - np.inf]
df_x418 = df_x417[df_x417['fgrow_log'] != - np.inf]
df_x428 = df_x427[df_x427['fgrow_log'] != - np.inf]
df_x438 = df_x437[df_x437['fgrow_log'] != - np.inf]
df_x448 = df_x447[df_x447['fgrow_log'] != - np.inf]
df_x458 = df_x457[df_x457['fgrow_log'] != - np.inf]
df_x468 = df_x467[df_x467['fgrow_log'] != - np.inf]
df_x478 = df_x477[df_x477['fgrow_log'] != - np.inf]
df_x488 = df_x487[df_x487['fgrow_log'] != - np.inf]
df_x498 = df_x497[df_x497['fgrow_log'] != - np.inf]

df_x508 = df_x507[df_x507['fgrow_log'] != - np.inf]
df_x518 = df_x517[df_x517['fgrow_log'] != - np.inf]
df_x528 = df_x527[df_x527['fgrow_log'] != - np.inf]
df_x538 = df_x537[df_x537['fgrow_log'] != - np.inf]
df_x548 = df_x547[df_x547['fgrow_log'] != - np.inf]
df_x558 = df_x557[df_x557['fgrow_log'] != - np.inf]
df_x568 = df_x567[df_x567['fgrow_log'] != - np.inf]
df_x578 = df_x577[df_x577['fgrow_log'] != - np.inf]
df_x588 = df_x587[df_x587['fgrow_log'] != - np.inf]
df_x598 = df_x597[df_x597['fgrow_log'] != - np.inf]

df_x608 = df_x607[df_x607['fgrow_log'] != - np.inf]
df_x618 = df_x617[df_x617['fgrow_log'] != - np.inf]
df_x628 = df_x627[df_x627['fgrow_log'] != - np.inf]
df_x638 = df_x637[df_x637['fgrow_log'] != - np.inf]
df_x648 = df_x647[df_x647['fgrow_log'] != - np.inf]

# %%
# step 9

df_x019 = df_x018[df_x018['revenue'] != 0.0]
df_x029 = df_x028[df_x028['revenue'] != 0.0]
df_x039 = df_x038[df_x038['revenue'] != 0.0]
df_x049 = df_x048[df_x048['revenue'] != 0.0]
df_x059 = df_x058[df_x058['revenue'] != 0.0]
df_x069 = df_x068[df_x068['revenue'] != 0.0]
df_x079 = df_x078[df_x078['revenue'] != 0.0]
df_x089 = df_x088[df_x088['revenue'] != 0.0]
df_x099 = df_x098[df_x098['revenue'] != 0.0]

df_x109 = df_x108[df_x108['revenue'] != 0.0]
df_x119 = df_x118[df_x118['revenue'] != 0.0]
df_x129 = df_x128[df_x128['revenue'] != 0.0]
df_x139 = df_x138[df_x138['revenue'] != 0.0]
df_x149 = df_x148[df_x148['revenue'] != 0.0]
df_x159 = df_x158[df_x158['revenue'] != 0.0]
df_x169 = df_x168[df_x168['revenue'] != 0.0]
df_x179 = df_x178[df_x178['revenue'] != 0.0]
df_x189 = df_x188[df_x188['revenue'] != 0.0]
df_x199 = df_x198[df_x198['revenue'] != 0.0]

df_x209 = df_x208[df_x208['revenue'] != 0.0]
df_x219 = df_x218[df_x218['revenue'] != 0.0]
df_x229 = df_x228[df_x228['revenue'] != 0.0]
df_x239 = df_x238[df_x238['revenue'] != 0.0]
df_x249 = df_x248[df_x248['revenue'] != 0.0]
df_x259 = df_x258[df_x258['revenue'] != 0.0]
df_x269 = df_x268[df_x268['revenue'] != 0.0]
df_x279 = df_x278[df_x278['revenue'] != 0.0]
df_x289 = df_x288[df_x288['revenue'] != 0.0]
df_x299 = df_x298[df_x298['revenue'] != 0.0]

df_x309 = df_x308[df_x308['revenue'] != 0.0]
df_x319 = df_x318[df_x318['revenue'] != 0.0]
df_x329 = df_x328[df_x328['revenue'] != 0.0]
df_x339 = df_x338[df_x338['revenue'] != 0.0]
df_x349 = df_x348[df_x348['revenue'] != 0.0]
df_x359 = df_x358[df_x358['revenue'] != 0.0]
df_x369 = df_x368[df_x368['revenue'] != 0.0]
df_x379 = df_x378[df_x378['revenue'] != 0.0]
df_x389 = df_x388[df_x388['revenue'] != 0.0]
df_x399 = df_x398[df_x398['revenue'] != 0.0]

df_x409 = df_x408[df_x408['revenue'] != 0.0]
df_x419 = df_x418[df_x418['revenue'] != 0.0]
df_x429 = df_x428[df_x428['revenue'] != 0.0]
df_x439 = df_x438[df_x438['revenue'] != 0.0]
df_x449 = df_x448[df_x448['revenue'] != 0.0]
df_x459 = df_x458[df_x458['revenue'] != 0.0]
df_x469 = df_x468[df_x468['revenue'] != 0.0]
df_x479 = df_x478[df_x478['revenue'] != 0.0]
df_x489 = df_x488[df_x488['revenue'] != 0.0]
df_x499 = df_x498[df_x498['revenue'] != 0.0]

df_x509 = df_x508[df_x508['revenue'] != 0.0]
df_x519 = df_x518[df_x518['revenue'] != 0.0]
df_x529 = df_x528[df_x528['revenue'] != 0.0]
df_x539 = df_x538[df_x538['revenue'] != 0.0]
df_x549 = df_x548[df_x548['revenue'] != 0.0]
df_x559 = df_x558[df_x558['revenue'] != 0.0]
df_x569 = df_x568[df_x568['revenue'] != 0.0]
df_x579 = df_x578[df_x578['revenue'] != 0.0]
df_x589 = df_x588[df_x588['revenue'] != 0.0]
df_x599 = df_x598[df_x598['revenue'] != 0.0]

df_x609 = df_x608[df_x608['revenue'] != 0.0]
df_x619 = df_x618[df_x618['revenue'] != 0.0]
df_x629 = df_x628[df_x628['revenue'] != 0.0]
df_x639 = df_x638[df_x638['revenue'] != 0.0]
df_x649 = df_x648[df_x648['revenue'] != 0.0]

# %%
# step 10

df_x0110 = df_x019[df_x019['logrevenue'] > 0.0]
df_x0210 = df_x029[df_x029['logrevenue'] > 0.0]
df_x0310 = df_x039[df_x039['logrevenue'] > 0.0]
df_x0410 = df_x049[df_x049['logrevenue'] > 0.0]
df_x0510 = df_x059[df_x059['logrevenue'] > 0.0]
df_x0610 = df_x069[df_x069['logrevenue'] > 0.0]
df_x0710 = df_x079[df_x079['logrevenue'] > 0.0]
df_x0810 = df_x089[df_x089['logrevenue'] > 0.0]
df_x0910 = df_x099[df_x099['logrevenue'] > 0.0]

df_x1010 = df_x109[df_x109['logrevenue'] > 0.0]
df_x1110 = df_x119[df_x119['logrevenue'] > 0.0]
df_x1210 = df_x129[df_x129['logrevenue'] > 0.0]
df_x1310 = df_x139[df_x139['logrevenue'] > 0.0]
df_x1410 = df_x149[df_x149['logrevenue'] > 0.0]
df_x1510 = df_x159[df_x159['logrevenue'] > 0.0]
df_x1610 = df_x169[df_x169['logrevenue'] > 0.0]
df_x1710 = df_x179[df_x179['logrevenue'] > 0.0]
df_x1810 = df_x189[df_x189['logrevenue'] > 0.0]
df_x1910 = df_x199[df_x199['logrevenue'] > 0.0]

df_x2010 = df_x209[df_x209['logrevenue'] > 0.0]
df_x2110 = df_x219[df_x219['logrevenue'] > 0.0]
df_x2210 = df_x229[df_x229['logrevenue'] > 0.0]
df_x2310 = df_x239[df_x239['logrevenue'] > 0.0]
df_x2410 = df_x249[df_x249['logrevenue'] > 0.0]
df_x2510 = df_x259[df_x259['logrevenue'] > 0.0]
df_x2610 = df_x269[df_x269['logrevenue'] > 0.0]
df_x2710 = df_x279[df_x279['logrevenue'] > 0.0]
df_x2810 = df_x289[df_x289['logrevenue'] > 0.0]
df_x2910 = df_x299[df_x299['logrevenue'] > 0.0]

df_x3010 = df_x309[df_x309['logrevenue'] > 0.0]
df_x3110 = df_x319[df_x319['logrevenue'] > 0.0]
df_x3210 = df_x329[df_x329['logrevenue'] > 0.0]
df_x3310 = df_x339[df_x339['logrevenue'] > 0.0]
df_x3410 = df_x349[df_x349['logrevenue'] > 0.0]
df_x3510 = df_x359[df_x359['logrevenue'] > 0.0]
df_x3610 = df_x369[df_x369['logrevenue'] > 0.0]
df_x3710 = df_x379[df_x379['logrevenue'] > 0.0]
df_x3810 = df_x389[df_x389['logrevenue'] > 0.0]
df_x3910 = df_x399[df_x399['logrevenue'] > 0.0]

df_x4010 = df_x409[df_x409['logrevenue'] > 0.0]
df_x4110 = df_x419[df_x419['logrevenue'] > 0.0]
df_x4210 = df_x429[df_x429['logrevenue'] > 0.0]
df_x4310 = df_x439[df_x439['logrevenue'] > 0.0]
df_x4410 = df_x449[df_x449['logrevenue'] > 0.0]
df_x4510 = df_x459[df_x459['logrevenue'] > 0.0]
df_x4610 = df_x469[df_x469['logrevenue'] > 0.0]
df_x4710 = df_x479[df_x479['logrevenue'] > 0.0]
df_x4810 = df_x489[df_x489['logrevenue'] > 0.0]
df_x4910 = df_x499[df_x499['logrevenue'] > 0.0]

df_x5010 = df_x509[df_x509['logrevenue'] > 0.0]
df_x5110 = df_x519[df_x519['logrevenue'] > 0.0]
df_x5210 = df_x529[df_x529['logrevenue'] > 0.0]
df_x5310 = df_x539[df_x539['logrevenue'] > 0.0]
df_x5410 = df_x549[df_x549['logrevenue'] > 0.0]
df_x5510 = df_x559[df_x559['logrevenue'] > 0.0]
df_x5610 = df_x569[df_x569['logrevenue'] > 0.0]
df_x5710 = df_x579[df_x579['logrevenue'] > 0.0]
df_x5810 = df_x589[df_x589['logrevenue'] > 0.0]
df_x5910 = df_x599[df_x599['logrevenue'] > 0.0]

df_x6010 = df_x609[df_x609['logrevenue'] > 0.0]
df_x6110 = df_x619[df_x619['logrevenue'] > 0.0]
df_x6210 = df_x629[df_x629['logrevenue'] > 0.0]
df_x6310 = df_x639[df_x639['logrevenue'] > 0.0]
df_x6410 = df_x649[df_x649['logrevenue'] > 0.0]

df_x0110
# Out:
#      year   id      revenue  logrevenue  fgrow_log
# 0    2018    0  500343000.0   20.030804   0.027717
# 1    2018    1  244363000.0   19.314165   0.171957
# 2    2018    2  242137000.0   19.305014   0.023268
# 3    2018    3  229234000.0   19.250254   0.147229
# 4    2018    4  201159000.0   19.119606   0.117532
# ..    ...  ...          ...         ...        ...
# 448  2018  448    5504800.0   15.521131   0.113430
# 449  2018  449    5455000.0   15.512043   0.545772
# 450  2018  450    5453600.0   15.511786   0.166594
# 451  2018  451    5430000.0   15.507450   0.521159
# 452  2018  452    5428900.0   15.507247   0.178125
#
# [453 rows x 5 columns]

# %% [markdown]
# ## 4 append

# %%
dfx1 = df_x0110.append(df_x0210, ignore_index=True)
dfx2 = dfx1.append(df_x0310, ignore_index=True)
dfx3 = dfx2.append(df_x0410, ignore_index=True)
dfx4 = dfx3.append(df_x0510, ignore_index=True)
dfx5 = dfx4.append(df_x0610, ignore_index=True)
dfx6 = dfx5.append(df_x0710, ignore_index=True)
dfx7 = dfx6.append(df_x0810, ignore_index=True)
dfx8 = dfx7.append(df_x0910, ignore_index=True)
dfx9 = dfx8.append(df_x1010, ignore_index=True)
dfx10 = dfx9.append(df_x1110, ignore_index=True)
dfx11 = dfx10.append(df_x1210, ignore_index=True)
dfx12 = dfx11.append(df_x1310, ignore_index=True)
dfx13 = dfx12.append(df_x1410, ignore_index=True)
dfx14 = dfx13.append(df_x1510, ignore_index=True)
dfx15 = dfx14.append(df_x1610, ignore_index=True)
dfx16 = dfx15.append(df_x1710, ignore_index=True)
dfx17 = dfx16.append(df_x1810, ignore_index=True)
dfx18 = dfx17.append(df_x1910, ignore_index=True)
dfx19 = dfx18.append(df_x2010, ignore_index=True)
dfx20 = dfx19.append(df_x2110, ignore_index=True)
dfx21 = dfx20.append(df_x2210, ignore_index=True)
dfx22 = dfx21.append(df_x2310, ignore_index=True)
dfx23 = dfx22.append(df_x2410, ignore_index=True)
dfx24 = dfx23.append(df_x2510, ignore_index=True)
dfx25 = dfx24.append(df_x2610, ignore_index=True)
dfx26 = dfx25.append(df_x2710, ignore_index=True)
dfx27 = dfx26.append(df_x2810, ignore_index=True)
dfx28 = dfx27.append(df_x2910, ignore_index=True)
dfx29 = dfx28.append(df_x3010, ignore_index=True)
dfx30 = dfx29.append(df_x3110, ignore_index=True)
dfx31 = dfx30.append(df_x3210, ignore_index=True)
dfx32 = dfx31.append(df_x3310, ignore_index=True)
dfx33 = dfx32.append(df_x3410, ignore_index=True)
dfx34 = dfx33.append(df_x3510, ignore_index=True)
dfx35 = dfx34.append(df_x3610, ignore_index=True)
dfx36 = dfx35.append(df_x3710, ignore_index=True)
dfx37 = dfx36.append(df_x3810, ignore_index=True)
dfx38 = dfx37.append(df_x3910, ignore_index=True)
dfx39 = dfx38.append(df_x4010, ignore_index=True)
dfx40 = dfx39.append(df_x4110, ignore_index=True)
dfx41 = dfx40.append(df_x4210, ignore_index=True)
dfx42 = dfx41.append(df_x4310, ignore_index=True)
dfx43 = dfx42.append(df_x4410, ignore_index=True)
dfx44 = dfx43.append(df_x4510, ignore_index=True)
dfx45 = dfx44.append(df_x4610, ignore_index=True)
dfx46 = dfx45.append(df_x4710, ignore_index=True)
dfx47 = dfx46.append(df_x4810, ignore_index=True)
dfx48 = dfx47.append(df_x4910, ignore_index=True)
dfx49 = dfx48.append(df_x5010, ignore_index=True)
dfx50 = dfx49.append(df_x5110, ignore_index=True)
dfx51 = dfx50.append(df_x5210, ignore_index=True)
dfx52 = dfx51.append(df_x5310, ignore_index=True)
dfx53 = dfx52.append(df_x5410, ignore_index=True)
dfx54 = dfx53.append(df_x5510, ignore_index=True)
dfx55 = dfx54.append(df_x5610, ignore_index=True)
dfx56 = dfx55.append(df_x5710, ignore_index=True)
dfx57 = dfx56.append(df_x5810, ignore_index=True)
dfx58 = dfx57.append(df_x5910, ignore_index=True)
dfx59 = dfx58.append(df_x6010, ignore_index=True)
dfx60 = dfx59.append(df_x6110, ignore_index=True)
dfx61 = dfx60.append(df_x6210, ignore_index=True)
dfx62 = dfx61.append(df_x6310, ignore_index=True)
df_us = dfx62.append(df_x6410, ignore_index=True)

# %% [markdown]
# ## 5 save and display

# %%
df_us.to_csv('data/us_toprevenue.csv')

# %%
fq.scatterplot(df_us, x='logrevenue', xlabel='Log Size (Log Revenue)')
