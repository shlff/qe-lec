# %% [markdown]
# # 11_mean_firm_growth_v2

# %%
import numpy as np
import pandas as pd

import fs_qe as fq

# %% [markdown]
# # 1 pre-process the data

# %% [markdown]
# ## 1.1 Without chopping

# %%
df4_c1 = fq.pre_process()
df4_c1
# Out:
#          count     id  year        tasset    fgrow_log
# 0            1  34255  2016  2.000000e+00  -348.124009
# 1            2  34951  2015  2.000000e+00  -125.276297
# 2            3  34948  2015  2.000000e+00  -504.985601
# 3            4  34944  2017  2.000000e+00 -1206.776702
# 4            5  34941  2018  2.000000e+00  -201.490302
# ...        ...    ...   ...           ...          ...
# 211932  211933     64  2013  4.024149e+09   -11.126915
# 211933  211934     64  2017  4.449977e+09     9.223826
# 211934  211935     64  2016  4.453337e+09     0.075478
# 211935  211936     64  2015  4.484765e+09     0.703239
# 211936  211937     64  2014  4.497774e+09     0.289651
#
# [211937 rows x 5 columns]

# %% [markdown]
# ## 1.2 with chopping

# %%
df4_c2 = fq.pre_process(file='data/usa_chop_log8.csv')

# %% [markdown]
# # 2 implementation
#
# There is a good article about binning data with methods ``qcut`` and ``cut``, please find [here](https://pbpython.com/pandas-qcut-cut.html).
#
# All the following bins enable our observations evenly cut.
# - That is, for each bin in the same plot, it has the same number of observations.

# %% [markdown]
# ## 2.1 without chopping
#
# ### 2.1.1 two bins

# %%
fq.barplot(df4_c1, bar=2)

# %% [markdown]
# ### 2.1.2 three bins

# %%
fq.barplot(df4_c1, bar=3)

# %% [markdown]
# ### 2.1.3 four bins

# %%
fq.barplot(df4_c1, bar=4)

# %% [markdown]
# ### 2.1.4 five bins

# %%
fq.barplot(df4_c1, bar=5)

# %% [markdown]
# ### 2.1.5 six bins

# %%
fq.barplot(df4_c1, bar=6)

# %% [markdown]
# ### 2.1.6 ten bins

# %%
fq.barplot(df4_c1, bar=10)

# %% [markdown]
# ### 2.1.7 one hundred bins

# %%
fq.barplot(df4_c1, bar=100)

# %% [markdown]
# ## 2.2 with chopping
#
# ### 2.2.1 two bins

# %%
fq.barplot(df4_c2, bar=2)

# %% [markdown]
# ### 2.2.2 three bins

# %%
fq.barplot(df4_c2, bar=3)

# %% [markdown]
# ### 2.2.3 four bins

# %%
fq.barplot(df4_c2, bar=4)

# %% [markdown]
# ### 2.2.4 five bins

# %%
fq.barplot(df4_c2, bar=5)

# %% [markdown]
# ### 2.2.5 six bins

# %%
fq.barplot(df4_c2, bar=6)

# %% [markdown]
# ### 2.2.6 ten bins

# %%
fq.barplot(df4_c2, bar=10)

# %% [markdown]
# ### 2.2.7 one hundred bins

# %%
fq.barplot(df4_c2, bar=100)
